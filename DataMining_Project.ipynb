# %%
import csv
import pandas as pd
import codecs
import xlrd
from pandas import DataFrame, Series
from itertools import islice

# Prove Excel Float -> Date works
xlrd.xldate_as_tuple(41152.1250578704,0)

# Create list of house ids
house_id = range(1,10)
house_id.append(13)

for id in house_id:
    
    # Read in each house's file
    print "House ",id
    f = codecs.open("Circuit_"+str(id)+".csv", encoding='iso-8859-1')

    # Read in file
    dataset_df = pd.read_csv(f, header=5)
    
    # Drop extra columns
    dataset_df = dataset_df.drop(dataset_df.columns[6:], axis=1)
    # Drop NANs
    dataset_df=dataset_df.dropna()
    
    # Sanity Check
    print dataset_df[0:5]
    
    # Add columns for date data
    dataset_df['month'] = dataset_df.syncdate.apply(lambda x: xlrd.xldate_as_tuple(x,0)[1])
    dataset_df['day'] = dataset_df.syncdate.apply(lambda x: xlrd.xldate_as_tuple(x,0)[2])
    dataset_df['hour'] = dataset_df.syncdate.apply(lambda x: xlrd.xldate_as_tuple(x,0)[3])
    dataset_df['minute'] = dataset_df.syncdate.apply(lambda x: xlrd.xldate_as_tuple(x,0)[4])
    dataset_df['second'] = dataset_df.syncdate.apply(lambda x: xlrd.xldate_as_tuple(x,0)[5])
    
    # Set date as index
    dataset_df=dataset_df.set_index('syncdate')
    print len(dataset_df)
    print dataset_df.ix[0:5]
    
    # Group by hour
    hour_group = dataset_df.groupby(['hour'])
    hour_df = hour_group.mean()
    print "hourdf"
    print type(hour_df)
    print hour_df.columns
    print hour_df[0:5]
    
    # Scatter average watts by hour
    plt.title("Average Watts per Hour");
    plt.scatter(hour_df.index,hour_df['watts'])
    plt.show()
    
    # Scatter average watts by hour
    plt.title("Average Credit per Hour");
    plt.scatter(hour_df.index,hour_df['cr'])
    plt.show()
    
    print len(dataset_df[dataset_df['watts']!=0.0])
    # Scatter average watts by hour
    plt.title("Watts used per Credit");
    plt.scatter(dataset_df[dataset_df['watts']!=0.0]['cr'],dataset_df[dataset_df['watts']!=0.0]['watts'])
    plt.text(66, 65, str(dataset_df[dataset_df['watts']!=0.0]['cr'].corr(dataset_df[dataset_df['watts']!=0.0]['watts'])))
    plt.show()
    
    plt.scatter(dataset_df['cr'],dataset_df['watts'])    
    plt.show()
        
        
    # Plot each column
    for col in dataset_df.columns[1:5]:
        print col
        dataset_df[col].plot(title=col)
        plt.show()
        
        #plt.text(dataset_df.index.corr(dataset_df['watts']))
        plt.show()
# Out:
# House  1
#    cid  syncdate  dwatts  nwatts  watts     cr
# 0    1  41152.13  334.79   23.82   0.00  606.7
# 1    1  41152.17  334.81   23.82   0.27  606.7
# 2    1  41152.17  334.81   23.82   0.00  606.7
# 3    1  41152.18  334.82   23.82   0.00  606.7
# 4    1  41152.21  345.78   23.82  30.68  602.1
# 1036
#           cid  dwatts  nwatts  watts     cr  month  day  hour  minute  second
# syncdate
# 41152.13    1  334.79   23.82   0.00  606.7      8   31     3       7      12
# 41152.17    1  334.81   23.82   0.27  606.7      8   31     4       4      48
# 41152.17    1  334.81   23.82   0.00  606.7      8   31     4       4      48
# 41152.18    1  334.82   23.82   0.00  606.7      8   31     4      19      12
# 41152.21    1  345.78   23.82  30.68  602.1      8   31     5       2      24
# hourdf
# <class 'pandas.core.frame.DataFrame'>
# Index([cid, dwatts, nwatts, watts, cr, month, day, minute, second], dtype=object)
#       cid     dwatts     nwatts     watts          cr     month        day     minute  \
# hour
# 0       1  57.280262  23.081467  2.790933  230.276533  9.213333  13.386667  28.106667
# 1       1  53.041081  19.310270  1.218919  247.415676  9.243243  12.621622  51.486486
# 2       1  18.378571   5.208571  4.781429  192.960000  9.000000  20.142857  21.714286
# 3       1  56.935814  18.545116  2.107442  251.051628  9.162791  13.046512   9.627907
# 4       1  94.076250  25.230250  1.839500  257.882250  9.150000  14.600000   8.075000
#
#          second
# hour
# 0     18.560000
# 1     12.648649
# 2     13.714286
# 3     15.069767
# 4     41.100000
# 508
# dwatts
# nwatts
# watts
# cr
# House  2
#    cid  syncdate  dwatts  nwatts  watts    cr
# 0    2  41152.13  129.61    22.5      0 -0.24
# 1    2  41152.17  129.61    22.5      0 -0.24
# 2    2  41152.17  129.61    22.5      0 -0.24
# 3    2  41152.18  129.61    22.5      0 -0.24
# 4    2  41152.21  129.61    22.5      0 -0.24
# 1036
#           cid  dwatts  nwatts  watts    cr  month  day  hour  minute  second
# syncdate
# 41152.13    2  129.61    22.5      0 -0.24      8   31     3       7      12
# 41152.17    2  129.61    22.5      0 -0.24      8   31     4       4      48
# 41152.17    2  129.61    22.5      0 -0.24      8   31     4       4      48
# 41152.18    2  129.61    22.5      0 -0.24      8   31     4      19      12
# 41152.21    2  129.61    22.5      0 -0.24      8   31     5       2      24
# hourdf
# <class 'pandas.core.frame.DataFrame'>
# Index([cid, dwatts, nwatts, watts, cr, month, day, minute, second], dtype=object)
#       cid     dwatts    nwatts  watts         cr     month        day     minute  \
# hour
# 0       2  11.532400  7.815200      0  85.010800  9.213333  13.386667  28.106667
# 1       2   9.832703  6.535676      0  81.434595  9.243243  12.621622  51.486486
# 2       2   3.244286  3.207143      0  59.862857  9.000000  20.142857  21.714286
# 3       2  12.083721  6.754884      0  80.315814  9.162791  13.046512   9.627907
# 4       2  23.097500  9.179750      0  74.492000  9.150000  14.600000   8.075000
#
#          second
# hour
# 0     18.560000
# 1     12.648649
# 2     13.714286
# 3     15.069767
# 4     41.100000
# 78
# dwatts
# nwatts
# watts
# cr
# House  3
#    cid  syncdate  dwatts  nwatts  watts    cr
# 0    3  41152.13  118.27    48.7      0  0.12
# 1    3  41152.17  118.27    48.7      0  0.12
# 2    3  41152.17  118.27    48.7      0  0.12
# 3    3  41152.18  118.28    48.7      0  0.12
# 4    3  41152.21  118.28    48.7      0  0.12
# 1036
#           cid  dwatts  nwatts  watts    cr  month  day  hour  minute  second
# syncdate
# 41152.13    3  118.27    48.7      0  0.12      8   31     3       7      12
# 41152.17    3  118.27    48.7      0  0.12      8   31     4       4      48
# 41152.17    3  118.27    48.7      0  0.12      8   31     4       4      48
# 41152.18    3  118.28    48.7      0  0.12      8   31     4      19      12
# 41152.21    3  118.28    48.7      0  0.12      8   31     5       2      24
# hourdf
# <class 'pandas.core.frame.DataFrame'>
# Index([cid, dwatts, nwatts, watts, cr, month, day, minute, second], dtype=object)
#       cid     dwatts     nwatts     watts         cr     month        day     minute  \
# hour
# 0       3  19.337213  12.396000  0.366933  79.421333  9.213333  13.386667  28.106667
# 1       3  15.960811   8.741892  0.825946  89.718378  9.243243  12.621622  51.486486
# 2       3   1.854286   1.622857  0.000000  50.035714  9.000000  20.142857  21.714286
# 3       3  19.873488   9.352791  2.491163  85.305814  9.162791  13.046512   9.627907
# 4       3  31.103500  14.907500  1.122750  81.188750  9.150000  14.600000   8.075000
#
#          second
# hour
# 0     18.560000
# 1     12.648649
# 2     13.714286
# 3     15.069767
# 4     41.100000
# 232
# dwatts
# nwatts
# watts
# cr
# House  4
#    cid  syncdate  dwatts  nwatts  watts      cr
# 0    5  41152.13   94.79   14.42      0  225.79
# 1    5  41152.17   94.87   14.42      0  225.77
# 2    5  41152.17   94.87   14.42      0  225.77
# 3    5  41152.18   94.87   14.42      0  225.77
# 4    5  41152.21   94.87   14.42      0  225.77
# 1036
#           cid  dwatts  nwatts  watts      cr  month  day  hour  minute  second
# syncdate
# 41152.13    5   94.79   14.42      0  225.79      8   31     3       7      12
# 41152.17    5   94.87   14.42      0  225.77      8   31     4       4      48
# 41152.17    5   94.87   14.42      0  225.77      8   31     4       4      48
# 41152.18    5   94.87   14.42      0  225.77      8   31     4      19      12
# 41152.21    5   94.87   14.42      0  225.77      8   31     5       2      24
# hourdf
# <class 'pandas.core.frame.DataFrame'>
# Index([cid, dwatts, nwatts, watts, cr, month, day, minute, second], dtype=object)
#       cid     dwatts    nwatts     watts          cr     month        day     minute  \
# hour
# 0       5  17.578498  9.711067  0.065467  355.401067  9.213333  13.386667  28.106667
# 1       5  14.710270  7.576757  0.770541  364.858108  9.243243  12.621622  51.486486
# 2       5   4.024286  2.825714  0.157143  350.167143  9.000000  20.142857  21.714286
# 3       5  15.815349  7.180000  0.485814  356.879070  9.162791  13.046512   9.627907
# 4       5  26.493750  9.886750  0.125000  334.847750  9.150000  14.600000   8.075000
#
#          second
# hour
# 0     18.560000
# 1     12.648649
# 2     13.714286
# 3     15.069767
# 4     41.100000
# 223
# dwatts
# nwatts
# watts
# cr
# House  5
#    cid  syncdate  dwatts  nwatts  watts      cr
# 0    5  41152.13   94.79   14.42      0  225.79
# 1    5  41152.17   94.87   14.42      0  225.77
# 2    5  41152.17   94.87   14.42      0  225.77
# 3    5  41152.18   94.87   14.42      0  225.77
# 4    5  41152.21   94.87   14.42      0  225.77
# 1036
#           cid  dwatts  nwatts  watts      cr  month  day  hour  minute  second
# syncdate
# 41152.13    5   94.79   14.42      0  225.79      8   31     3       7      12
# 41152.17    5   94.87   14.42      0  225.77      8   31     4       4      48
# 41152.17    5   94.87   14.42      0  225.77      8   31     4       4      48
# 41152.18    5   94.87   14.42      0  225.77      8   31     4      19      12
# 41152.21    5   94.87   14.42      0  225.77      8   31     5       2      24
# hourdf
# <class 'pandas.core.frame.DataFrame'>
# Index([cid, dwatts, nwatts, watts, cr, month, day, minute, second], dtype=object)
#       cid     dwatts    nwatts     watts          cr     month        day     minute  \
# hour
# 0       5  17.578498  9.711067  0.065467  355.401067  9.213333  13.386667  28.106667
# 1       5  14.710270  7.576757  0.770541  364.858108  9.243243  12.621622  51.486486
# 2       5   4.024286  2.825714  0.157143  350.167143  9.000000  20.142857  21.714286
# 3       5  15.815349  7.180000  0.485814  356.879070  9.162791  13.046512   9.627907
# 4       5  26.493750  9.886750  0.125000  334.847750  9.150000  14.600000   8.075000
#
#          second
# hour
# 0     18.560000
# 1     12.648649
# 2     13.714286
# 3     15.069767
# 4     41.100000
# 223
# dwatts
# nwatts
# watts
# cr
# House  6
#    cid  syncdate  dwatts  nwatts  watts     cr
# 0    6  41152.13   83.45   10.44      0  61.95
# 1    6  41152.17   83.45   10.44      0  61.95
# 2    6  41152.17   83.45   10.44      0  61.95
# 3    6  41152.18   83.45   10.44      0  61.95
# 4    6  41152.21   83.45   10.44      0  61.95
# 1036
#           cid  dwatts  nwatts  watts     cr  month  day  hour  minute  second
# syncdate
# 41152.13    6   83.45   10.44      0  61.95      8   31     3       7      12
# 41152.17    6   83.45   10.44      0  61.95      8   31     4       4      48
# 41152.17    6   83.45   10.44      0  61.95      8   31     4       4      48
# 41152.18    6   83.45   10.44      0  61.95      8   31     4      19      12
# 41152.21    6   83.45   10.44      0  61.95      8   31     5       2      24
# hourdf
# <class 'pandas.core.frame.DataFrame'>
# Index([cid, dwatts, nwatts, watts, cr, month, day, minute, second], dtype=object)
#       cid     dwatts    nwatts     watts          cr     month        day     minute  \
# hour
# 0       6  11.557438  6.506000  0.266933  116.841067  9.213333  13.386667  28.106667
# 1       6  10.468649  5.422432  0.269459  124.402162  9.243243  12.621622  51.486486
# 2       6   2.888571  1.867143  0.000000   63.461429  9.000000  20.142857  21.714286
# 3       6  11.934651  5.417442  1.119070  118.062558  9.162791  13.046512   9.627907
# 4       6  20.358500  7.254750  0.472250  110.670000  9.150000  14.600000   8.075000
#
#          second
# hour
# 0     18.560000
# 1     12.648649
# 2     13.714286
# 3     15.069767
# 4     41.100000
